# %%
import pandas as pd

# Let's see what we're working with here
anime_frame = pd.read_csv('data/AnimeList.csv')
anime_frame.columns
# Out:
# /home/joe/.local/share/virtualenvs/anime_jupyter-VLjT5OPb/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Index(['anime_id', 'title', 'title_english', 'title_japanese',
#        'title_synonyms', 'image_url', 'type', 'source', 'episodes', 'status',
#        'airing', 'aired_string', 'aired', 'duration', 'rating', 'score',
#        'scored_by', 'rank', 'popularity', 'members', 'favorites', 'background',
#        'premiered', 'broadcast', 'related', 'producer', 'licensor', 'studio',
#        'genre', 'opening_theme', 'ending_theme'],
#       dtype='object')

# %%
# Looks like there's a bunch of data that I don't need
# Let's filter the columns down to ones I care about
columns = ['title', 'title_english', 'score', 'popularity', 'genre']
anime = anime_frame[columns]
anime
# Out:
#                                        title              title_english  \
# 0                              Inu x Boku SS  Inu X Boku Secret Service
# 1                           Seto no Hanayome      My Bride is a Mermaid
# 2                         Shugo Chara!! Doki         Shugo Chara!! Doki
# 3                              Princess Tutu              Princess Tutu
# 4                        Bakuman. 3rd Season                   Bakuman.
# ...                                      ...                        ...
# 14473             Gutchonpa Omoshiro Hanashi                        NaN
# 14474                   Geba Geba Shou Time!                        NaN
# 14475            Godzilla: Hoshi wo Kuu Mono                        NaN
# 14476  Nippon Mukashibanashi: Sannen Netarou                        NaN
# 14477             Senjou no Valkyria Special                        NaN
#
#        score  popularity                                     genre
# ...

# %%
# What's in the User df?
user_frame = pd.read_csv('data/UserList.csv')
user_frame.columns
# Out:
# Index(['username', 'user_id', 'user_watching', 'user_completed', 'user_onhold',
#        'user_dropped', 'user_plantowatch', 'user_days_spent_watching',
#        'gender', 'location', 'birth_date', 'access_rank', 'join_date',
#        'last_online', 'stats_mean_score', 'stats_rewatched', 'stats_episodes'],
#       dtype='object')

# %%
# Now let's see what some of this data looks lilke
user_frame
# Out:
#                 username  user_id  user_watching  user_completed  user_onhold  \
# 0               karthiga  2255153              3              49            1
# 1       RedvelvetDaisuki  1897606             61             396           39
# 2              Damonashu    37326             45             195           27
# 3                  bskai   228342             25             414            2
# 4              shuzzable  2347781             36              72           16
# ...                  ...      ...            ...             ...          ...
# 302670      ScruffyPuffy  3119025              0              27            0
# 302671          Torasori  3975907             22             239            0
# 302672              onpc  1268417              5             169            2
# 302673            HMicca  1289601             11              73            2
# 302674        mini_kaila   236339              2              10            5
#
# ...

# %%
# remove unhelp values
anime_frame = anime_frame[anime_frame['popularity'] != 0]
anime_frame
# Out:
#        anime_id                                  title  \
# 0         11013                          Inu x Boku SS
# 1          2104                       Seto no Hanayome
# 2          5262                     Shugo Chara!! Doki
# 3           721                          Princess Tutu
# 4         12365                    Bakuman. 3rd Season
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                    title_english                  title_japanese  \
# 0      Inu X Boku Secret Service                          妖狐×僕SS
# 1          My Bride is a Mermaid                           瀬戸の花嫁
# 2             Shugo Chara!! Doki                     しゅごキャラ！！どきっ
# ...

# %%
# remove horny movies
clean_frame = anime_frame[~anime_frame.genre.str.contains('Hentai', na=False)]
# Now, let's see which ones are the most popular
clean_frame.sort_values('popularity').head(20)
# Out:
#        anime_id                             title  \
# 7913       1535                        Death Note
# 8123      16498                Shingeki no Kyojin
# 6296      11757                  Sword Art Online
# 2555       5114  Fullmetal Alchemist: Brotherhood
# 8863      30276                     One Punch Man
# 1235      22319                       Tokyo Ghoul
# 13606      6547                      Angel Beats!
# 2999       9253                       Steins;Gate
# 13726      1575   Code Geass: Hangyaku no Lelouch
# 4504         20                            Naruto
# 6487      19815                   No Game No Life
# 9176      10620                  Mirai Nikki (TV)
# 19         4224                         Toradora!
# 5437       9919                    Ao no Exorcist
# 6323      20507                          Noragami
# 8736        226                        Elfen Lied
# 5230      21881               Sword Art Online II
# 14          269                            Bleach
# ...
